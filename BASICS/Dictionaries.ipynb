# %%
d1 = { 1:"One",2:"Two" }
d1
# Out:
# {1: 'One', 2: 'Two'}

# %%
d2 = {"name":"xyz","name":"abc"}
d2
# Out:
# {'name': 'abc'}

# %%
d3 = { 'M1':[10,20,30,40],'M2':[20,40],'M3':False }
print(d3.values())
print(d3.items())
# Out:
# dict_values([[10, 20, 30, 40], [20, 40], False])
# dict_items([('M1', [10, 20, 30, 40]), ('M2', [20, 40]), ('M3', False)])

# %%
d3.update({'M3':True})
d3
# Out:
# {'M1': [10, 20, 30, 40], 'M2': [20, 40], 'M3': True}
