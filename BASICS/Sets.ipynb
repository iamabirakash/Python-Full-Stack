# %%
s1 = {1,2,3,4,5}
s2 = {'One','Two','Three'}
s3 = {0.1,1,1.1,2.1,3.1,4.3,5.2}
s4 = {True,False}
print(type(s1))
print(type(s2))
print(type(s3))
# Out:
# <class 'set'>
# <class 'set'>
# <class 'set'>

# %%
print(5 in s1)
print(15 in s1)
# Out:
# True
# False

# %%
print(s1[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(s1[0])
#
# TypeError: 'set' object is not subscriptable

# %%
s1.add(6)
print(s1)
s1.add(4)
print(s1)
s1.add('4')
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, '4'}

# %%
s2.add('Four')
print(s2)  # Unordered Set
s2.add('Five')
print(s2)
# Out:
# {'Three', 'One', 'Four', 'Two'}
# {'Two', 'Five', 'Four', 'Three', 'One'}

# %%
s2.remove('Two')
print(s2)
# Out:
# {'Five', 'Four', 'Three', 'One'}

# %%
s2.discard('Two')
print(s2)
# Out:
# {'Five', 'Four', 'Three', 'One'}

# %%
s2.pop()
print(s2)
# Out:
# {'Four', 'Three', 'One'}

# %%
s5 = s1.union(s3)
print(s5)
# Out:
# {0.1, 1, 2, 3, 4, 5, 1.1, 2.1, 3.1, 4.3, 5.2}

# %%
sett = {1,2,3,5,43,5}
sett
# Unique
# Out:
# {1, 2, 3, 5, 43}
